# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets\FuelConsumption_file.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\imoce\AppData\Local\Temp\ipykernel_16632\3896884189.py:1: SyntaxWarning: invalid escape sequence '\F'
#   df = pd.read_csv('datasets\FuelConsumption_file.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  \
# 0           0       2014  ACURA         ILX      COMPACT         2.0
# 1           1       2014  ACURA         ILX      COMPACT         2.4
# 2           2       2014  ACURA  ILX HYBRID      COMPACT         1.5
# 3           3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5
# 4           4       2014  ACURA     RDX AWD  SUV - SMALL         3.5
#
#    CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          4          AS5        Z                   9.9                  6.7
# 1          4           M6        Z                  11.2                  7.7
# 2          4          AV7        Z                   6.0                  5.8
# 3          6          AS6        Z                  12.7                  9.1
# 4          6          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ...

# %%
df.shape
# Out:
# (1067, 14)

# %%
df.describe()
# Out:
#         Unnamed: 0  MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count  1067.000000     1067.0  1067.000000  1067.000000           1067.000000
# mean    533.000000     2014.0     3.346298     5.794752             13.296532
# std     308.160672        0.0     1.415895     1.797447              4.101253
# min       0.000000     2014.0     1.000000     3.000000              4.600000
# 25%     266.500000     2014.0     2.000000     4.000000             10.250000
# 50%     533.000000     2014.0     3.400000     6.000000             12.600000
# 75%     799.500000     2014.0     4.300000     8.000000             15.550000
# max    1066.000000     2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df['FUELCONSUMPTION_COMB'].unique()
# Out:
# array([ 8.5,  9.6,  5.9, 11.1, 10.6, 10. , 10.1, 11.6,  9.2,  9.8, 10.4,
#        15.6, 14.7, 15.4,  8.8,  9.3, 10.2, 10.9,  8.3, 11.2, 11.3,  8.4,
#        12.5, 15.7, 10.5,  9.1, 13.2, 14.6, 17.7, 17.8, 13.3, 13.4, 12.6,
#        11.4, 12.4, 12.2, 12.9, 12.7, 10.3, 15.5, 13.9, 16.5, 14. , 19. ,
#         8.7,  6.7,  9.9,  7.9, 10.7, 13.8, 11. , 16.1, 11.9, 14.1, 12.1,
#        12.3, 11.5,  8.2,  9.5,  9. , 10.8, 12.8, 16.6, 14.8, 20.1, 16.4,
#        22.1, 11.8, 11.7, 12. ,  7.8,  7.1,  7.7, 16.2, 17. , 15.1, 15.9,
#        20.9, 21.5, 22.6, 18. , 18.8, 25.7, 18.2, 18.9, 25.8, 14.3,  8. ,
#        16.8, 16.9, 13. , 17.3,  7.5,  6.9, 18.4,  8.1, 14.4, 13.1,  8.6,
#         7.3,  7.2,  6.8,  6. , 21.9, 17.2, 22.5, 23. , 21.2, 18.3, 23.9,
#         9.4, 16. , 21.6, 16.7, 17.5, 19.7, 14.9, 20. , 19.9,  7.6,  6.6,
#         7. ,  8.9,  5.5,  4.8,  6.3,  6.2, 14.5, 15. , 18.1, 13.7, 13.5,
#        15.8,  9.7, 17.4, 21.4, 20.7,  5.6, 15.3,  7.4, 15.2, 14.2,  6.4,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
sns.scatterplot(data= df, x='FUELCONSUMPTION_COMB', y='CO2EMISSIONS')
# Out:
# <Axes: xlabel='FUELCONSUMPTION_COMB', ylabel='CO2EMISSIONS'>

# %%
data1 = df[['ENGINESIZE', 'CO2EMISSIONS']]
data2 = df[['FUELCONSUMPTION_COMB', 'CO2EMISSIONS']]

# %%
data2.corr()
# Out:
#                       FUELCONSUMPTION_COMB  CO2EMISSIONS
# FUELCONSUMPTION_COMB              1.000000      0.892129
# CO2EMISSIONS                      0.892129      1.000000

# %%
sns.boxplot(data=df, x='MODELYEAR', y='CO2EMISSIONS')
# Out:
# <Axes: xlabel='MODELYEAR', ylabel='CO2EMISSIONS'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
corr_mat = df.drop(['FUELTYPE', 'TRANSMISSION', 'VEHICLECLASS', 'MODEL', 'MAKE'], axis=1).corr()
sns.heatmap(data=corr_mat, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
X = df['FUELCONSUMPTION_COMB'].values.reshape(-1,1)
y = df['CO2EMISSIONS'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[19]])[0].round(2)
# Out:
# 375.14

# %%
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

# %%
print('Mean squared error is: %.2f' % mean_squared_error(y_test, y_test_pred))
print('R2 score is: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Mean squared error is: 781.20
# R2 score is: 0.80
